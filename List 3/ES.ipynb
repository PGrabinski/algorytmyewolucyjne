# %% [markdown]
# # $ES(\mu$, $\lambda)$ and $ES(\mu+\lambda)$ algorithms

# %%
import numpy as np
import wandb
from tqdm.notebook import tqdm

# %%
class ES_search:
    problem_dimensionality: int
    parents_number: int
    descendants_number: int
    tau: float
    tau_zero: float

    def __init__(self, problem_dimensionality, parents_number, initial_min, initial_max, descendants_number, tau, tau_zero, fitness_function,
                 sum_populations=True, ranking_resampling=True, **args) -> None:
        self.problem_dimensionality = problem_dimensionality
        self.parents_number = parents_number
        self.descendants_number = descendants_number
        self.tau = tau
        self.tau_zero = tau_zero
        self.fitness_function = fitness_function
        self.sum_populations = sum_populations
        self.initial_min = initial_min
        self.initial_max = initial_max
        self.ranking_resampling = ranking_resampling
        self.best_chromosome = None

        self.initialize_population()

    def initialize_population(self):
        genes = np.random.uniform(self.initial_min, self.initial_max, (self.parents_number, self.problem_dimensionality)) 
        mutation_rates = np.random.uniform(self.initial_min, self.initial_max, (self.parents_number, self.problem_dimensionality)) 
        self.population = (genes, mutation_rates)

    def evaluate_population(self, generation):
        genes, mutation_rates = self.population
        fitness = np.array([self.fitness_function(gene) for gene in genes])
        wandb.log({"generation": generation, "fitness_max": fitness.max(), "fitness_min": fitness.min(), "fitness_avg": fitness.mean()})
        if not self.best_chromosome or fitness.max() > self.best_chromosome['fitness']:
            best_id = np.argmax(fitness.max())
            self.best_chromosome = {
                'fitness': fitness.max(),
                'genes': genes[best_id],
                'mutation_rates': mutation_rates[best_id],
                'generation': generation
                                   }
            wandb.log({"best_chromosome": self.best_chromosome})
        return fitness

    def evolve(self, max_generations):
        self.evaluate_population(0)
        for generation in range(max_generations):
            fitness = self.evolve_generation(generation)
            print(f"Generation {generation} Max fitness: {fitness.max()} Min fitness: {fitness.min()} Avg fitness: {fitness.mean()}")

    def select_parents(self, genes, mutation_rates, fitness):
        indices_to_be_mutated = np.random.choice(self.parents_number, self.descendants_number, replace=False)
        return genes[indices_to_be_mutated], mutation_rates[indices_to_be_mutated]

    def evolve_generation(self, generation):
        genes, mutation_rates = self.population
        fitness = self.evaluate_population(generation)
        genes_to_be_mutated, mutation_rates_to_be_mutated = self.select_parents(genes, mutation_rates, fitness)
        descendant_genes, descendant_mutation_rates = self.generate_descendants(genes_to_be_mutated, mutation_rates_to_be_mutated)

        self.population = self.recombine_populations(genes, mutation_rates, fitness, descendant_genes, descendant_mutation_rates)

        return fitness

    def generate_descendants(self, genes, mutation_rates):
        epsilons = np.random.normal(0, self.tau**2, (self.descendants_number, self.problem_dimensionality))
        epsilons_zero = np.random.normal(0, self.tau_zero**2)
        descendant_genes = genes + epsilons
        descendant_mutation_rates = mutation_rates + np.exp(epsilons_zero + epsilons)
        return descendant_genes, descendant_mutation_rates
    
    def recombine_populations(self, parent_genes, parent_mutation_rates, parent_fitness, descendant_genes, descendant_mutation_rates):
        if self.sum_populations:
            genes = np.vstack([parent_genes, descendant_genes])
            mutation_rates = np.vstack([parent_mutation_rates, descendant_mutation_rates])
            fitness = np.concatenate([parent_fitness, np.array([self.fitness_function(gene) for gene in descendant_genes])])
            if self.ranking_resampling:
                indices = fitness.argsort()[-self.parents_number:]
                return genes[indices], mutation_rates[indices]
            else:
                indices = np.random.choice(self.parents_number+self.descendants_number, self.parents_number, replace=True, p=fitness/fitness.sum())
                return genes[indices], mutation_rates[indices]
        else:
            return descendant_genes, descendant_mutation_rates

# %% [markdown]
# ## Benchmark functions

# %%
def griewank(x):
    fr = 4000
    s = (x**2).sum()
    p = np.array([np.cos(x_i/np.sqrt(i+1)) for i, x_i in enumerate(x)]).prod()
    y = s/fr - p + 1
    return y

# %%
def rastrigin(x):
    n = x.shape[0]
    s = np.sum([x_i**2-10*np.cos(2*np.pi*x_i) for x_i in x])
    y = 10*n+s
    return y

# %%
def schwefel(x):
    s = np.sum(-x*np.sin(np.sqrt(np.abs(x))))
    y = 418.9829*x.shape[0]+s
    return y

# %%
def michalewicz(x):
    m = 10
    s = np.sum([np.sin(x_i)*(np.sin(i*x_i**2/np.pi))**(2*m) for i, x_i in enumerate(x)])
    return -s

# %%
def sum_squares(x):
    s = np.sum([(i+1)*x_i**2 for i, x_i in enumerate(x)])
    return s

# %% [markdown]
# ## Experiments

# %%
experiments = [
    # {
    #     'problem_dimensionality': 2,
    #     'parents_number': 2500,
    #     'initial_min': -400,
    #     'initial_max': 400,
    #     'descendants_number': 500,
    #     'tau': 0.1,
    #     'tau_zero':0.1,
    #     'fitness_function': lambda x: -griewank(x),
    #     'fitness_name': 'griewank',
    #     'generations': 1000,
    #     'known_minimum': 0,
    # },
    # {
    #     'problem_dimensionality': 2,
    #     'parents_number': 2500,
    #     'initial_min': -5,
    #     'initial_max': 5,
    #     'descendants_number': 500,
    #     'tau': 0.1,
    #     'tau_zero':0.1,
    #     'fitness_function': lambda x: -rastrigin(x),
    #     'fitness_name': 'rastrigin',
    #     'generations': 1000,
    #     'known_minimum': 0
    # },
    # {
    #     'problem_dimensionality': 5,
    #     'parents_number': 2500,
    #     'initial_min': -5,
    #     'initial_max': 5,
    #     'descendants_number': 500,
    #     'tau': 0.1,
    #     'tau_zero':0.1,
    #     'fitness_function': lambda x: -rastrigin(x),
    #     'fitness_name': 'rastrigin',
    #     'generations': 1000,
    #     'known_minimum': 0
    # },
    # {
    #     'problem_dimensionality': 10,
    #     'parents_number': 2500,
    #     'initial_min': -5,
    #     'initial_max': 5,
    #     'descendants_number': 500,
    #     'tau': 0.1,
    #     'tau_zero':0.1,
    #     'fitness_function': lambda x: -rastrigin(x),
    #     'fitness_name': 'rastrigin',
    #     'generations': 1000,
    #     'known_minimum': 0
    # },
    # {
    #     'problem_dimensionality': 2,
    #     'parents_number': 2500,
    #     'initial_min': -450,
    #     'initial_max': 450,
    #     'descendants_number': 500,
    #     'tau': 0.1,
    #     'tau_zero':0.1,
    #     'fitness_function': lambda x: -schwefel(x),
    #     'fitness_name': 'schewefel',
    #     'generations': 1000,
    #     'known_minimum': 0
    # },
    # {
    #     'problem_dimensionality': 2,
    #     'parents_number': 2500,
    #     'initial_min': 0.1,
    #     'initial_max': 0.9*np.pi,
    #     'descendants_number': 500,
    #     'tau': 0.1,
    #     'tau_zero':0.1,
    #     'fitness_function': lambda x: -michalewicz(x),
    #     'fitness_name': 'michalewicz',
    #     'generations': 1000,
    #     'known_minimum': -1.8013
    # },
    # {
    #     'problem_dimensionality': 2,
    #     'parents_number': 2500,
    #     'initial_min': -8,
    #     'initial_max': 8,
    #     'descendants_number': 500,
    #     'tau': 0.1,
    #     'tau_zero':0.1,
    #     'fitness_function': lambda x: -sum_squares(x),
    #     'fitness_name': 'sum_squares',
    #     'generations': 1000,
    #     'known_minimum': 0
    # },
    # {
    #     'problem_dimensionality': 2,
    #     'parents_number': 2500,
    #     'initial_min': -450,
    #     'initial_max': 450,
    #     'descendants_number': 500,
    #     'tau': 0.1,
    #     'tau_zero':0.1,
    #     'fitness_function': lambda x: -schwefel(x),
    #     'fitness_name': 'schewefel',
    #     'generations': 10000,
    #     'known_minimum': 0
    # },
    # {
    #     'problem_dimensionality': 2,
    #     'parents_number': 2500,
    #     'initial_min': 0.1,
    #     'initial_max': 0.9*np.pi,
    #     'descendants_number': 500,
    #     'tau': 0.1,
    #     'tau_zero':0.1,
    #     'fitness_function': lambda x: -michalewicz(x),
    #     'fitness_name': 'michalewicz',
    #     'generations': 10000,
    #     'known_minimum': -1.8013
    # },
    # {
    #     'problem_dimensionality': 2,
    #     'parents_number': 2500,
    #     'initial_min': -400,
    #     'initial_max': 400,
    #     'descendants_number': 500,
    #     'tau': 0.1,
    #     'tau_zero': 0.1,
    #     'fitness_function': lambda x: -griewank(x),
    #     'fitness_name': 'griewank',
    #     'generations': 10000,
    #     'known_minimum': 0,
    # },
    # {
    #     'problem_dimensionality': 2,
    #     'parents_number': 2500,
    #     'initial_min': -450,
    #     'initial_max': 450,
    #     'descendants_number': 100,
    #     'tau': 0.5,
    #     'tau_zero':0.5,
    #     'fitness_function': lambda x: -schwefel(x),
    #     'fitness_name': 'schewefel',
    #     'generations': 5000,
    #     'known_minimum': 0
    # },
    # {
    #     'problem_dimensionality': 2,
    #     'parents_number': 2500,
    #     'initial_min': 0.1,
    #     'initial_max': 0.9*np.pi,
    #     'descendants_number': 500,
    #     'tau': 0.25,
    #     'tau_zero':0.25,
    #     'fitness_function': lambda x: -michalewicz(x),
    #     'fitness_name': 'michalewicz',
    #     'generations': 1000,
    #     'known_minimum': -1.8013
    # },
    # {
    #     'problem_dimensionality': 2,
    #     'parents_number': 2500,
    #     'initial_min': 0.1,
    #     'initial_max': 0.9*np.pi,
    #     'descendants_number': 100,
    #     'tau': 0.25,
    #     'tau_zero':0.25,
    #     'fitness_function': lambda x: -michalewicz(x),
    #     'fitness_name': 'michalewicz',
    #     'generations': 5000,
    #     'known_minimum': -1.8013
    # },
    {
        'problem_dimensionality': 2,
        'parents_number': 2500,
        'initial_min': -400,
        'initial_max': 400,
        'descendants_number': 100,
        'tau': 0.5,
        'tau_zero': 0.5,
        'fitness_function': lambda x: -griewank(x),
        'fitness_name': 'griewank',
        'generations': 10000,
        'known_minimum': 0,
    },
]

# %%
def run_experiment(config):
    es = ES_search(**config)
    wandb.init(config=config)
    es.evolve(config['generations'])

# %%
for experiment in tqdm(experiments):
    run_experiment(experiment)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# Finishing last run (ID:py0ex78l) before initializing another...
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# wandb: WARNING Source type is set to 'repo' but some required information is missing from the environment. A job will not be created from this run. See https://docs.wandb.ai/guides/launch/create-job
# VBox(children=(Label(value='0.002 MB of 0.533 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=0.004132…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>fitness_avg</td><td>▁███████████████████████████████████████</td></tr><tr><td>fitness_max</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>fitness_min</td><td>▁███████████████████████████████████████</td></tr><tr><td>generation</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>fitness_avg</td><td>0.8013</td></tr><tr><td>fitness_max</td><td>0.8013</td></tr><tr><td>fitness_min</td><td>0.8013</td></tr><tr><td>generation</td><td>4999</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">firm-meadow-45</strong> at: <a href='https://wandb.ai/pgrabinski/Algorytmy%20Ewolucyjne-List%203_List%203/runs/py0ex78l' target="_blank">https://wandb.ai/pgrabinski/Algorytmy%20Ewolucyjne-List%203_List%203/runs/py0ex78l</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20231204_173727-py0ex78l/logs</code>
# Successfully finished last run (ID:py0ex78l). Initializing new run:<br/>
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.011112598644427232, max=1.0…
# wandb version 0.16.0 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.15.12
# Run data is saved locally in <code>/workspaces/Algorytmy Ewolucyjne/List 3/wandb/run-20231204_175933-5fms8ssd</code>
# Syncing run <strong><a href='https://wandb.ai/pgrabinski/Algorytmy%20Ewolucyjne-List%203_List%203/runs/5fms8ssd' target="_blank">rose-water-46</a></strong> to <a href='https://wandb.ai/pgrabinski/Algorytmy%20Ewolucyjne-List%203_List%203' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/pgrabinski/Algorytmy%20Ewolucyjne-List%203_List%203' target="_blank">https://wandb.ai/pgrabinski/Algorytmy%20Ewolucyjne-List%203_List%203</a>
#  View run at <a href='https://wandb.ai/pgrabinski/Algorytmy%20Ewolucyjne-List%203_List%203/runs/5fms8ssd' target="_blank">https://wandb.ai/pgrabinski/Algorytmy%20Ewolucyjne-List%203_List%203/runs/5fms8ssd</a>
# Generation 0 Max fitness: -0.268343921365924 Min fitness: -79.8764981969497 Avg fitness: -27.475336989991785
# Generation 1 Max fitness: -0.268343921365924 Min fitness: -61.22015597773209 Avg fitness: -25.825675650869826
# Generation 2 Max fitness: -0.268343921365924 Min fitness: -53.59016492243252 Avg fitness: -24.462996826635422
# Generation 3 Max fitness: -0.268343921365924 Min fitness: -48.268732539710875 Avg fitness: -23.40960795742299
# Generation 4 Max fitness: -0.268343921365924 Min fitness: -44.816465075409944 Avg fitness: -22.40145487982277
# Generation 5 Max fitness: -0.268343921365924 Min fitness: -42.3065554500819 Avg fitness: -21.553857070051322
# Generation 6 Max fitness: -0.268343921365924 Min fitness: -40.54360020827952 Avg fitness: -20.76267893376614
# Generation 7 Max fitness: -0.268343921365924 Min fitness: -39.059801739417935 Avg fitness: -19.984161605799528
# Generation 8 Max fitness: -0.268343921365924 Min fitness: -37.53433342355018 Avg fitness: -19.238066962962293
# Generation 9 Max fitness: -0.268343921365924 Min fitness: -35.93051506087655 Avg fitness: -18.535164695787994
# Generation 10 Max fitness: -0.268343921365924 Min fitness: -34.67480455146678 Avg fitness: -17.820872696021357
# Generation 11 Max fitness: -0.268343921365924 Min fitness: -33.251138198042945 Avg fitness: -17.145641241961822
# Generation 12 Max fitness: -0.268343921365924 Min fitness: -31.87230736385821 Avg fitness: -16.545301930946785
# Generation 13 Max fitness: -0.268343921365924 Min fitness: -30.34467367535578 Avg fitness: -15.970253689212168
# Generation 14 Max fitness: -0.268343921365924 Min fitness: -29.26101162210001 Avg fitness: -15.397827970923291
# Generation 15 Max fitness: -0.268343921365924 Min fitness: -28.044883496445117 Avg fitness: -14.85119422322155
# Generation 16 Max fitness: -0.268343921365924 Min fitness: -26.77082631060239 Avg fitness: -14.315375008496078
# Generation 17 Max fitness: -0.268343921365924 Min fitness: -26.026544640618642 Avg fitness: -13.812230020561879
# Generation 18 Max fitness: -0.268343921365924 Min fitness: -24.87445001588962 Avg fitness: -13.369196143949829
# Generation 19 Max fitness: -0.268343921365924 Min fitness: -23.86390867724869 Avg fitness: -12.951853963442689
# Generation 20 Max fitness: -0.268343921365924 Min fitness: -23.048433356970577 Avg fitness: -12.532744705020859
# Generation 21 Max fitness: -0.2533656379574969 Min fitness: -22.13026573386386 Avg fitness: -12.127050431282333
# Generation 22 Max fitness: -0.2533656379574969 Min fitness: -21.518859285831294 Avg fitness: -11.730722089894302
# Generation 23 Max fitness: -0.2533656379574969 Min fitness: -20.748923102324902 Avg fitness: -11.356380792320762
# Generation 24 Max fitness: -0.2533656379574969 Min fitness: -20.112214177000197 Avg fitness: -11.013944674890904
# Generation 25 Max fitness: -0.11075642453777068 Min fitness: -19.180172273586642 Avg fitness: -10.667505173915485
# Generation 26 Max fitness: -0.11075642453777068 Min fitness: -18.73703092764456 Avg fitness: -10.340553885159332
# Generation 27 Max fitness: -0.11075642453777068 Min fitness: -18.172616206295718 Avg fitness: -9.993899025027522
# Generation 28 Max fitness: -0.11075642453777068 Min fitness: -17.58262515581075 Avg fitness: -9.659835339464136
# Generation 29 Max fitness: -0.11075642453777068 Min fitness: -17.21193925496313 Avg fitness: -9.340626197277473
# Generation 30 Max fitness: -0.10280799281845854 Min fitness: -16.64925518995492 Avg fitness: -9.039739185256755
# Generation 31 Max fitness: -0.10280799281845854 Min fitness: -16.11975705956401 Avg fitness: -8.74098266478418
# Generation 32 Max fitness: -0.10280799281845854 Min fitness: -15.681183789030333 Avg fitness: -8.446723161227165
# Generation 33 Max fitness: -0.10280799281845854 Min fitness: -15.154057584076815 Avg fitness: -8.155546738553053
# Generation 34 Max fitness: -0.05499703071616513 Min fitness: -14.499304038624619 Avg fitness: -7.869769763298542
# Generation 35 Max fitness: -0.05499703071616513 Min fitness: -13.925436189762848 Avg fitness: -7.652386043039609
# Generation 36 Max fitness: -0.05499703071616513 Min fitness: -13.407701028831635 Avg fitness: -7.396997029150975
# Generation 37 Max fitness: -0.05499703071616513 Min fitness: -13.06225676697755 Avg fitness: -7.173158915630772
# Generation 38 Max fitness: -0.05499703071616513 Min fitness: -12.68019707964858 Avg fitness: -6.9601630771492955
# Generation 39 Max fitness: -0.05499703071616513 Min fitness: -12.115397585231703 Avg fitness: -6.750042065796423
# Generation 40 Max fitness: -0.05499703071616513 Min fitness: -11.649905679607642 Avg fitness: -6.553741846324058
# Generation 41 Max fitness: -0.05499703071616513 Min fitness: -11.358977147409766 Avg fitness: -6.337755654452995
# Generation 42 Max fitness: -0.05499703071616513 Min fitness: -11.023854643878721 Avg fitness: -6.140790241167034
# Generation 43 Max fitness: -0.05499703071616513 Min fitness: -10.760334174547323 Avg fitness: -5.935692070372695
# Generation 44 Max fitness: -0.05499703071616513 Min fitness: -10.436760854942012 Avg fitness: -5.766587588813649
# Generation 45 Max fitness: -0.05499703071616513 Min fitness: -9.990691038891384 Avg fitness: -5.587302592892743
# Generation 46 Max fitness: -0.05499703071616513 Min fitness: -9.54553174261516 Avg fitness: -5.41652626013785
# Generation 47 Max fitness: -0.05499703071616513 Min fitness: -9.167253646156853 Avg fitness: -5.258153796620877
# Generation 48 Max fitness: -0.05499703071616513 Min fitness: -8.835715324576778 Avg fitness: -5.093979910857463
# Generation 49 Max fitness: -0.05499703071616513 Min fitness: -8.632598755182855 Avg fitness: -4.9543802117579245
# Generation 50 Max fitness: -0.05499703071616513 Min fitness: -8.386731604780538 Avg fitness: -4.812835409592378
# Generation 51 Max fitness: -0.05499703071616513 Min fitness: -8.125730367933828 Avg fitness: -4.668351337087416
# Generation 52 Max fitness: -0.05499703071616513 Min fitness: -7.775619162749774 Avg fitness: -4.545984163491147
# Generation 53 Max fitness: -0.05499703071616513 Min fitness: -7.505603955446101 Avg fitness: -4.426016637752152
# Generation 54 Max fitness: -0.05499703071616513 Min fitness: -7.300271587881422 Avg fitness: -4.311763045808222
# Generation 55 Max fitness: -0.05499703071616513 Min fitness: -7.0909099355411875 Avg fitness: -4.206180301519068
# Generation 56 Max fitness: -0.05499703071616513 Min fitness: -6.887002577995088 Avg fitness: -4.104521514811802
# Generation 57 Max fitness: -0.05499703071616513 Min fitness: -6.69424449090245 Avg fitness: -4.009649645404225
# Generation 58 Max fitness: -0.05499703071616513 Min fitness: -6.484903038231934 Avg fitness: -3.901446361094412
# Generation 59 Max fitness: -0.05499703071616513 Min fitness: -6.351235410774638 Avg fitness: -3.802797135420832
# Generation 60 Max fitness: -0.05499703071616513 Min fitness: -6.181671695646174 Avg fitness: -3.703513971877696
# Generation 61 Max fitness: -0.05499703071616513 Min fitness: -6.043139012918004 Avg fitness: -3.6226980433632927
# Generation 62 Max fitness: -0.05499703071616513 Min fitness: -5.883256158327141 Avg fitness: -3.5284450671755017
# Generation 63 Max fitness: -0.05499703071616513 Min fitness: -5.6841550319371 Avg fitness: -3.438110140085563
# Generation 64 Max fitness: -0.05499703071616513 Min fitness: -5.548345877615404 Avg fitness: -3.34700393234808
# Generation 65 Max fitness: -0.05499703071616513 Min fitness: -5.455099811333079 Avg fitness: -3.2572134660021606
# Generation 66 Max fitness: -0.05499703071616513 Min fitness: -5.352868510055109 Avg fitness: -3.175709234634686
# Generation 67 Max fitness: -0.05499703071616513 Min fitness: -5.241630586550911 Avg fitness: -3.098760634746358
# Generation 68 Max fitness: -0.05499703071616513 Min fitness: -5.145233246160529 Avg fitness: -3.019643624909469
# Generation 69 Max fitness: -0.05499703071616513 Min fitness: -5.053904801007212 Avg fitness: -2.9409461632441767
# Generation 70 Max fitness: -0.05499703071616513 Min fitness: -4.95923772181342 Avg fitness: -2.8518204633053794
# Generation 71 Max fitness: -0.05499703071616513 Min fitness: -4.8478186856625305 Avg fitness: -2.774875142132573
# Generation 72 Max fitness: -0.05499703071616513 Min fitness: -4.7127515795099955 Avg fitness: -2.701596840553387
# Generation 73 Max fitness: -0.05499703071616513 Min fitness: -4.49818524247553 Avg fitness: -2.6280294033664218
# Generation 74 Max fitness: -0.05499703071616513 Min fitness: -4.3253722311354075 Avg fitness: -2.559257163658747
# Generation 75 Max fitness: -0.05499703071616513 Min fitness: -4.152465716203934 Avg fitness: -2.4955828662257513
# Generation 76 Max fitness: -0.05499703071616513 Min fitness: -4.029558770340373 Avg fitness: -2.435712150252569
# Generation 77 Max fitness: -0.05499703071616513 Min fitness: -3.8537932066248266 Avg fitness: -2.367342400869158
# Generation 78 Max fitness: -0.05499703071616513 Min fitness: -3.698245606491767 Avg fitness: -2.315228649711726
# Generation 79 Max fitness: -0.05499703071616513 Min fitness: -3.575693068523224 Avg fitness: -2.2648027710116714
# Generation 80 Max fitness: -0.05499703071616513 Min fitness: -3.4656088384703065 Avg fitness: -2.220570221723772
# Generation 81 Max fitness: -0.05499703071616513 Min fitness: -3.396758082548665 Avg fitness: -2.1662274175984177
# Generation 82 Max fitness: -0.05499703071616513 Min fitness: -3.332917106536894 Avg fitness: -2.117860621114021
# Generation 83 Max fitness: -0.02403844518245002 Min fitness: -3.2565644652586796 Avg fitness: -2.0659507281429477
# Generation 84 Max fitness: -0.02403844518245002 Min fitness: -3.1798122000641427 Avg fitness: -2.013090881413977
# Generation 85 Max fitness: -0.02403844518245002 Min fitness: -3.1197351784786904 Avg fitness: -1.9639260148029505
# Generation 86 Max fitness: -0.02403844518245002 Min fitness: -3.045877275717424 Avg fitness: -1.9198676004621058
# Generation 87 Max fitness: -0.02403844518245002 Min fitness: -2.9780087892642575 Avg fitness: -1.8799583552696975
# Generation 88 Max fitness: -0.02403844518245002 Min fitness: -2.9049481469176683 Avg fitness: -1.835219424377359
# Generation 89 Max fitness: -0.02403844518245002 Min fitness: -2.8224599306184732 Avg fitness: -1.7921156096102633
# Generation 90 Max fitness: -0.02403844518245002 Min fitness: -2.76246232482348 Avg fitness: -1.7532235099420836
# Generation 91 Max fitness: -0.02403844518245002 Min fitness: -2.70302635809904 Avg fitness: -1.7121049627698304
# Generation 92 Max fitness: -0.02403844518245002 Min fitness: -2.635865703103004 Avg fitness: -1.6771759875444756
# Generation 93 Max fitness: -0.02403844518245002 Min fitness: -2.5710092707530197 Avg fitness: -1.6409477866599176
# Generation 94 Max fitness: -0.02403844518245002 Min fitness: -2.5111223997870606 Avg fitness: -1.6030548464986902
# Generation 95 Max fitness: -0.02403844518245002 Min fitness: -2.4618545511237744 Avg fitness: -1.5706248170293373
# Generation 96 Max fitness: -0.02403844518245002 Min fitness: -2.4084234279655257 Avg fitness: -1.533617571309619
# Generation 97 Max fitness: -0.02403844518245002 Min fitness: -2.367163035955475 Avg fitness: -1.5017987914827762
# Generation 98 Max fitness: -0.02403844518245002 Min fitness: -2.31409292451722 Avg fitness: -1.469535360223976
# Generation 99 Max fitness: -0.02403844518245002 Min fitness: -2.265198582657575 Avg fitness: -1.4318963320855325
# Generation 100 Max fitness: -0.02403844518245002 Min fitness: -2.216479264910288 Avg fitness: -1.3983963677320062
# Generation 101 Max fitness: -0.02403844518245002 Min fitness: -2.163247506185696 Avg fitness: -1.36662225251273
# Generation 102 Max fitness: -0.02403844518245002 Min fitness: -2.1242686454777875 Avg fitness: -1.3326583130897722
# Generation 103 Max fitness: -0.02403844518245002 Min fitness: -2.0804512609597334 Avg fitness: -1.3043890498308073
# Generation 104 Max fitness: -0.02403844518245002 Min fitness: -2.030443605759896 Avg fitness: -1.2767157117991756
# Generation 105 Max fitness: -0.02403844518245002 Min fitness: -1.9892096752234747 Avg fitness: -1.2460316400898406
# Generation 106 Max fitness: -0.02403844518245002 Min fitness: -1.945632684881101 Avg fitness: -1.21865994648183
# Generation 107 Max fitness: -0.02403844518245002 Min fitness: -1.8942751948185623 Avg fitness: -1.1882368435842339
# Generation 108 Max fitness: -0.02403844518245002 Min fitness: -1.8421048162341447 Avg fitness: -1.1618977395631278
# Generation 109 Max fitness: -0.02403844518245002 Min fitness: -1.7779015198606776 Avg fitness: -1.1375033667143648
# Generation 110 Max fitness: -0.02403844518245002 Min fitness: -1.7086338933137486 Avg fitness: -1.1160577694759752
# Generation 111 Max fitness: -0.02403844518245002 Min fitness: -1.6716982344063454 Avg fitness: -1.095563164736546
# Generation 112 Max fitness: -0.02403844518245002 Min fitness: -1.6414562990771995 Avg fitness: -1.0725402162548783
# Generation 113 Max fitness: -0.018192514448186703 Min fitness: -1.5968405814689945 Avg fitness: -1.0482159724314337
# Generation 114 Max fitness: -0.010847806489207579 Min fitness: -1.5488724219215917 Avg fitness: -1.0261843449302939
# Generation 115 Max fitness: -0.010847806489207579 Min fitness: -1.5128664068283648 Avg fitness: -1.0059695951309346
# Generation 116 Max fitness: -0.010847806489207579 Min fitness: -1.4736140531346331 Avg fitness: -0.9873164480210098
# Generation 117 Max fitness: -0.010847806489207579 Min fitness: -1.441629802236088 Avg fitness: -0.9682737008841134
# Generation 118 Max fitness: -0.010847806489207579 Min fitness: -1.4124797364574455 Avg fitness: -0.9503172958257473
# Generation 119 Max fitness: -0.010847806489207579 Min fitness: -1.382329604277556 Avg fitness: -0.9339586366520088
# Generation 120 Max fitness: -0.010847806489207579 Min fitness: -1.3591450959411766 Avg fitness: -0.916086394552476
# Generation 121 Max fitness: -0.010847806489207579 Min fitness: -1.3381794342643802 Avg fitness: -0.9007867043003258
# Generation 122 Max fitness: -0.010847806489207579 Min fitness: -1.3215130753386752 Avg fitness: -0.8829447533491482
# Generation 123 Max fitness: -0.010847806489207579 Min fitness: -1.2971822783326254 Avg fitness: -0.8652815624037649
# Generation 124 Max fitness: -0.010847806489207579 Min fitness: -1.2788791861632853 Avg fitness: -0.8483604989982426
# Generation 125 Max fitness: -0.010847806489207579 Min fitness: -1.263946329163176 Avg fitness: -0.8341113233976098
# Generation 126 Max fitness: -0.010847806489207579 Min fitness: -1.2485718949950242 Avg fitness: -0.8190140831906274
# Generation 127 Max fitness: -0.010847806489207579 Min fitness: -1.2302952385528592 Avg fitness: -0.8015168894182582
# Generation 128 Max fitness: -0.010847806489207579 Min fitness: -1.2121597513603917 Avg fitness: -0.7849149381806648
# Generation 129 Max fitness: -0.010847806489207579 Min fitness: -1.1920108925878656 Avg fitness: -0.7680846071250479
# Generation 130 Max fitness: -0.010847806489207579 Min fitness: -1.1726332261839754 Avg fitness: -0.7521959963528613
# Generation 131 Max fitness: -0.010847806489207579 Min fitness: -1.1506652218646094 Avg fitness: -0.7359496705210806
# Generation 132 Max fitness: -0.010847806489207579 Min fitness: -1.1308082675544084 Avg fitness: -0.721431540210834
# Generation 133 Max fitness: -0.010847806489207579 Min fitness: -1.1060902661923149 Avg fitness: -0.7066896027998837
# Generation 134 Max fitness: -0.010847806489207579 Min fitness: -1.0917983879385744 Avg fitness: -0.6914089225646854
# Generation 135 Max fitness: -0.010847806489207579 Min fitness: -1.0754455360962005 Avg fitness: -0.6766725865712022
# Generation 136 Max fitness: -0.010847806489207579 Min fitness: -1.0597836428528986 Avg fitness: -0.6613389597812169
# Generation 137 Max fitness: -0.010847806489207579 Min fitness: -1.0454421917405088 Avg fitness: -0.6450972354554942
# Generation 138 Max fitness: -0.010847806489207579 Min fitness: -1.0271150011333536 Avg fitness: -0.6288997052681389
# Generation 139 Max fitness: -0.010734726396200878 Min fitness: -1.0106594635278412 Avg fitness: -0.6113281670236843
# Generation 140 Max fitness: -0.010734726396200878 Min fitness: -0.9936615573138213 Avg fitness: -0.5972009539186254
# Generation 141 Max fitness: -0.010734726396200878 Min fitness: -0.9796381562354584 Avg fitness: -0.5835420980552303
# Generation 142 Max fitness: -0.010734726396200878 Min fitness: -0.9517986752858154 Avg fitness: -0.5688720501504831
# Generation 143 Max fitness: -0.010734726396200878 Min fitness: -0.9326879880130668 Avg fitness: -0.554042344970256
# Generation 144 Max fitness: -0.010734726396200878 Min fitness: -0.909894084546665 Avg fitness: -0.5392496274229086
# Generation 145 Max fitness: -0.010734726396200878 Min fitness: -0.8845402750447602 Avg fitness: -0.5264408355796779
# Generation 146 Max fitness: -0.010734726396200878 Min fitness: -0.8617928966684054 Avg fitness: -0.5149356402523467
# Generation 147 Max fitness: -0.010734726396200878 Min fitness: -0.8421299272891687 Avg fitness: -0.500762398662156
# Generation 148 Max fitness: -0.010734726396200878 Min fitness: -0.8228836313975589 Avg fitness: -0.48884511551837057
# Generation 149 Max fitness: -0.010734726396200878 Min fitness: -0.8038851014984705 Avg fitness: -0.4761351194889783
# Generation 150 Max fitness: -0.007822942746361639 Min fitness: -0.785253970080795 Avg fitness: -0.4637047860871425
# Generation 151 Max fitness: -0.007822942746361639 Min fitness: -0.7632786483759447 Avg fitness: -0.4520376106405385
# Generation 152 Max fitness: -0.007822942746361639 Min fitness: -0.7441730487681316 Avg fitness: -0.4413058573737717
# Generation 153 Max fitness: -0.007822942746361639 Min fitness: -0.7270181951214557 Avg fitness: -0.43024574378153446
# Generation 154 Max fitness: -0.007822942746361639 Min fitness: -0.7081020595391545 Avg fitness: -0.4196420122840385
# Generation 155 Max fitness: -0.007822942746361639 Min fitness: -0.693931533424072 Avg fitness: -0.40886457891499345
# Generation 156 Max fitness: -0.007822942746361639 Min fitness: -0.6753036441580151 Avg fitness: -0.40010078555994194
# Generation 157 Max fitness: -0.007822942746361639 Min fitness: -0.6589972691647085 Avg fitness: -0.390018035409603
# Generation 158 Max fitness: -0.007822942746361639 Min fitness: -0.6432095716094703 Avg fitness: -0.37990071777064
# Generation 159 Max fitness: -0.007822942746361639 Min fitness: -0.6306183389910311 Avg fitness: -0.3712928946209404
# Generation 160 Max fitness: -0.007822942746361639 Min fitness: -0.6161138958365187 Avg fitness: -0.3633719320752969
# Generation 161 Max fitness: -0.006262170833029712 Min fitness: -0.5994824588689278 Avg fitness: -0.35373851327750006
# Generation 162 Max fitness: -0.006262170833029712 Min fitness: -0.5838216314617561 Avg fitness: -0.3449532696189075
# Generation 163 Max fitness: -0.006262170833029712 Min fitness: -0.5673257154227687 Avg fitness: -0.3369566843160701
# Generation 164 Max fitness: -0.006262170833029712 Min fitness: -0.5531418419016281 Avg fitness: -0.3281808334351083
# Generation 165 Max fitness: -0.006262170833029712 Min fitness: -0.5418892562143698 Avg fitness: -0.31920921524320495
# Generation 166 Max fitness: -0.0009585915361166597 Min fitness: -0.5290909355602755 Avg fitness: -0.31067153981609097
# Generation 167 Max fitness: -0.0009585915361166597 Min fitness: -0.5188616714165946 Avg fitness: -0.3030411421005806
# Generation 168 Max fitness: -0.0009585915361166597 Min fitness: -0.5082741548518452 Avg fitness: -0.29531719225593195
# Generation 169 Max fitness: -0.0009585915361166597 Min fitness: -0.4987579022896982 Avg fitness: -0.28828412194107866
# Generation 170 Max fitness: -0.0009585915361166597 Min fitness: -0.48550032076630356 Avg fitness: -0.28119854140410816
# Generation 171 Max fitness: -0.0009585915361166597 Min fitness: -0.4760705246349676 Avg fitness: -0.2748925743351064
# Generation 172 Max fitness: -0.0009585915361166597 Min fitness: -0.4643540501132981 Avg fitness: -0.26849398023545745
# Generation 173 Max fitness: -0.0009585915361166597 Min fitness: -0.451877876337731 Avg fitness: -0.2617852598327605
# Generation 174 Max fitness: -0.0009585915361166597 Min fitness: -0.4421118647512604 Avg fitness: -0.2550728311162457
# Generation 175 Max fitness: -0.0009585915361166597 Min fitness: -0.4310331793266349 Avg fitness: -0.24775315552551516
# Generation 176 Max fitness: -0.0009585915361166597 Min fitness: -0.4198116912476232 Avg fitness: -0.2408443096274617
# Generation 177 Max fitness: -0.0009585915361166597 Min fitness: -0.40985608895168035 Avg fitness: -0.23448063209928802
# Generation 178 Max fitness: -0.0009585915361166597 Min fitness: -0.3989287997180754 Avg fitness: -0.2288610809030973
# Generation 179 Max fitness: -0.0009585915361166597 Min fitness: -0.39026300184088736 Avg fitness: -0.22217206036770645
# Generation 180 Max fitness: -0.0009585915361166597 Min fitness: -0.38170580139192845 Avg fitness: -0.2154888967717807
# Generation 181 Max fitness: -0.0009585915361166597 Min fitness: -0.37462189521002587 Avg fitness: -0.2089125001252074
# Generation 182 Max fitness: -0.0009585915361166597 Min fitness: -0.3647979322763968 Avg fitness: -0.20378166313274287
# Generation 183 Max fitness: -0.0009585915361166597 Min fitness: -0.3574574094080528 Avg fitness: -0.19853525353380752
# Generation 184 Max fitness: -0.0009585915361166597 Min fitness: -0.3478567668417307 Avg fitness: -0.19294617966353783
# Generation 185 Max fitness: -0.0009585915361166597 Min fitness: -0.3372591210131415 Avg fitness: -0.18719513274945979
# Generation 186 Max fitness: -0.0009585915361166597 Min fitness: -0.32927670200794634 Avg fitness: -0.18224873335307284
# Generation 187 Max fitness: -0.0009585915361166597 Min fitness: -0.3222620518394319 Avg fitness: -0.1782173025484949
# Generation 188 Max fitness: -0.0009585915361166597 Min fitness: -0.3152830969365964 Avg fitness: -0.17344432822995132
# Generation 189 Max fitness: -0.0009585915361166597 Min fitness: -0.30745529989522513 Avg fitness: -0.16842580003631502
# Generation 190 Max fitness: -0.0009585915361166597 Min fitness: -0.3000907356004212 Avg fitness: -0.1631254177064952
# Generation 191 Max fitness: -0.0009585915361166597 Min fitness: -0.29218442024848046 Avg fitness: -0.15844726153649824
# Generation 192 Max fitness: -0.0009585915361166597 Min fitness: -0.2850543061054711 Avg fitness: -0.15360803360750405
# Generation 193 Max fitness: -0.0009585915361166597 Min fitness: -0.2783681746360147 Avg fitness: -0.14885905364712168
# Generation 194 Max fitness: -0.0009585915361166597 Min fitness: -0.2726674703660392 Avg fitness: -0.14512132060992947
# Generation 195 Max fitness: -0.0009585915361166597 Min fitness: -0.2675905626836791 Avg fitness: -0.14092864296075194
# Generation 196 Max fitness: -0.0009585915361166597 Min fitness: -0.2624466879599372 Avg fitness: -0.13655367535980828
# Generation 197 Max fitness: -0.0009585915361166597 Min fitness: -0.2574474540249344 Avg fitness: -0.13212032883946676
# Generation 198 Max fitness: -0.0009585915361166597 Min fitness: -0.25275002088586707 Avg fitness: -0.12794623762380694
# Generation 199 Max fitness: -0.0009585915361166597 Min fitness: -0.24846418660942016 Avg fitness: -0.12429617549889024
# Generation 200 Max fitness: -0.0009585915361166597 Min fitness: -0.24426390536988507 Avg fitness: -0.12015687989725665
# Generation 201 Max fitness: -0.0009585915361166597 Min fitness: -0.23641062821885594 Avg fitness: -0.11631499521432824
# Generation 202 Max fitness: -0.0009585915361166597 Min fitness: -0.22722775380651095 Avg fitness: -0.11224124590411022
# Generation 203 Max fitness: -0.0009585915361166597 Min fitness: -0.21861975379154464 Avg fitness: -0.10862599031142367
# Generation 204 Max fitness: -0.0009585915361166597 Min fitness: -0.21189112015150713 Avg fitness: -0.10541989776366163
# Generation 205 Max fitness: -0.0009585915361166597 Min fitness: -0.20412617404626532 Avg fitness: -0.10209238929362187
# Generation 206 Max fitness: -0.0009585915361166597 Min fitness: -0.19585429784339226 Avg fitness: -0.09874152853314255
# Generation 207 Max fitness: -0.0009585915361166597 Min fitness: -0.1886588122472771 Avg fitness: -0.09579094245736712
# Generation 208 Max fitness: -0.0009585915361166597 Min fitness: -0.18197634604670032 Avg fitness: -0.09303707545217396
# Generation 209 Max fitness: -0.0009585915361166597 Min fitness: -0.1762237955538558 Avg fitness: -0.09045875072523728
# Generation 210 Max fitness: -0.0009585915361166597 Min fitness: -0.17118951129298765 Avg fitness: -0.08797671920950186
# Generation 211 Max fitness: -0.0009585915361166597 Min fitness: -0.1647826581893551 Avg fitness: -0.0853865442255413
# Generation 212 Max fitness: -0.0009585915361166597 Min fitness: -0.1588466818908859 Avg fitness: -0.08266800675002466
# Generation 213 Max fitness: -0.0009585915361166597 Min fitness: -0.15507466402073733 Avg fitness: -0.08051671378921346
# Generation 214 Max fitness: -0.0009585915361166597 Min fitness: -0.15055293825539084 Avg fitness: -0.07814180243926531
# Generation 215 Max fitness: -0.00048384559331038357 Min fitness: -0.14542473419373347 Avg fitness: -0.0755486204257654
# Generation 216 Max fitness: -0.00048384559331038357 Min fitness: -0.14132382005741917 Avg fitness: -0.07340824423518953
# Generation 217 Max fitness: -0.00048384559331038357 Min fitness: -0.13708901263684747 Avg fitness: -0.07111909588101813
# Generation 218 Max fitness: -0.00048384559331038357 Min fitness: -0.13399031303798858 Avg fitness: -0.069197915302806
# Generation 219 Max fitness: -0.00048384559331038357 Min fitness: -0.13007344348378436 Avg fitness: -0.06742498308909395
# Generation 220 Max fitness: -0.00048384559331038357 Min fitness: -0.1257571512650365 Avg fitness: -0.06564132139958795
# Generation 221 Max fitness: -0.00048384559331038357 Min fitness: -0.12185533188013387 Avg fitness: -0.0640906155278788
# Generation 222 Max fitness: -0.00048384559331038357 Min fitness: -0.1187412903003725 Avg fitness: -0.06263762404429371
# Generation 223 Max fitness: -0.00048384559331038357 Min fitness: -0.11641596869239978 Avg fitness: -0.06112780010318965
# Generation 224 Max fitness: -0.00048384559331038357 Min fitness: -0.11332359116157331 Avg fitness: -0.05964102625313562
# Generation 225 Max fitness: -5.878005740189707e-05 Min fitness: -0.11088802452668589 Avg fitness: -0.05804197179288003
# Generation 226 Max fitness: -5.878005740189707e-05 Min fitness: -0.10746144262873925 Avg fitness: -0.05643475839064979
# Generation 227 Max fitness: -5.878005740189707e-05 Min fitness: -0.10487716918380996 Avg fitness: -0.05510788487668575
# Generation 228 Max fitness: -5.878005740189707e-05 Min fitness: -0.10251541806730935 Avg fitness: -0.053860316541589806
# Generation 229 Max fitness: -5.878005740189707e-05 Min fitness: -0.10011311601657014 Avg fitness: -0.05257782933450041
# Generation 230 Max fitness: -5.878005740189707e-05 Min fitness: -0.09773133741284301 Avg fitness: -0.051144210220140894
# Generation 231 Max fitness: -5.878005740189707e-05 Min fitness: -0.09554634874664969 Avg fitness: -0.050125339864751796
# Generation 232 Max fitness: -5.878005740189707e-05 Min fitness: -0.09315913635599227 Avg fitness: -0.04891828198769891
# Generation 233 Max fitness: -5.878005740189707e-05 Min fitness: -0.09016895851794926 Avg fitness: -0.04791989153272024
# Generation 234 Max fitness: -5.878005740189707e-05 Min fitness: -0.08826913869701536 Avg fitness: -0.046809183186832824
# Generation 235 Max fitness: -5.878005740189707e-05 Min fitness: -0.0855777295716581 Avg fitness: -0.04563065306656102
# Generation 236 Max fitness: -5.878005740189707e-05 Min fitness: -0.08336770628246948 Avg fitness: -0.044641561568822
# Generation 237 Max fitness: -5.878005740189707e-05 Min fitness: -0.08224057676639263 Avg fitness: -0.04391617695424582
# Generation 238 Max fitness: -5.878005740189707e-05 Min fitness: -0.0807474753241414 Avg fitness: -0.04312336832706859
# Generation 239 Max fitness: -5.878005740189707e-05 Min fitness: -0.07898165600459972 Avg fitness: -0.04229960108126792
# Generation 240 Max fitness: -5.878005740189707e-05 Min fitness: -0.07701048396942789 Avg fitness: -0.04136808957080417
# Generation 241 Max fitness: -5.878005740189707e-05 Min fitness: -0.07495914630496048 Avg fitness: -0.0404850762404426
# Generation 242 Max fitness: -5.878005740189707e-05 Min fitness: -0.07331668765445265 Avg fitness: -0.039526323750708886
# Generation 243 Max fitness: -5.878005740189707e-05 Min fitness: -0.07195057608885735 Avg fitness: -0.038693699224063814
# Generation 244 Max fitness: -5.878005740189707e-05 Min fitness: -0.07058678173952249 Avg fitness: -0.03802219955711138
# Generation 245 Max fitness: -5.878005740189707e-05 Min fitness: -0.06891787448345243 Avg fitness: -0.03725526199563486
# Generation 246 Max fitness: -5.878005740189707e-05 Min fitness: -0.06756473121462125 Avg fitness: -0.03663878982211212
# Generation 247 Max fitness: -5.878005740189707e-05 Min fitness: -0.06617185211498122 Avg fitness: -0.035972687535807825
# Generation 248 Max fitness: -5.878005740189707e-05 Min fitness: -0.06452481303759883 Avg fitness: -0.03533601597149305
# Generation 249 Max fitness: -5.878005740189707e-05 Min fitness: -0.06353879490493008 Avg fitness: -0.03483998037618014
# Generation 250 Max fitness: -5.878005740189707e-05 Min fitness: -0.06210550919121205 Avg fitness: -0.03421618878099335
# Generation 251 Max fitness: -5.878005740189707e-05 Min fitness: -0.060703461424349237 Avg fitness: -0.03361992157445455
# Generation 252 Max fitness: -5.878005740189707e-05 Min fitness: -0.05927665705155427 Avg fitness: -0.03291046319912306
# Generation 253 Max fitness: -5.878005740189707e-05 Min fitness: -0.058301544898449076 Avg fitness: -0.03243643500459613
# Generation 254 Max fitness: -5.878005740189707e-05 Min fitness: -0.05738444458936054 Avg fitness: -0.031915820741442516
# Generation 255 Max fitness: -5.878005740189707e-05 Min fitness: -0.0563072610901556 Avg fitness: -0.0314726207002171
# Generation 256 Max fitness: -5.878005740189707e-05 Min fitness: -0.05543253194367148 Avg fitness: -0.030906479037148694
# Generation 257 Max fitness: -5.878005740189707e-05 Min fitness: -0.054581775667471355 Avg fitness: -0.030339859906461642
# Generation 258 Max fitness: -5.878005740189707e-05 Min fitness: -0.05324420992441581 Avg fitness: -0.029806689448258913
# Generation 259 Max fitness: -5.878005740189707e-05 Min fitness: -0.052511394979799064 Avg fitness: -0.029423988493092856
# Generation 260 Max fitness: -5.878005740189707e-05 Min fitness: -0.05171681946678652 Avg fitness: -0.028934046115075312
# Generation 261 Max fitness: -5.878005740189707e-05 Min fitness: -0.0507112162751997 Avg fitness: -0.028356264018483734
# Generation 262 Max fitness: -5.878005740189707e-05 Min fitness: -0.0498445326386 Avg fitness: -0.028021253298159604
# Generation 263 Max fitness: -5.878005740189707e-05 Min fitness: -0.048832566442355896 Avg fitness: -0.027647350261505665
# Generation 264 Max fitness: -5.878005740189707e-05 Min fitness: -0.047720920098198394 Avg fitness: -0.02723581420011352
# Generation 265 Max fitness: -5.878005740189707e-05 Min fitness: -0.04696870697566646 Avg fitness: -0.02691357955251491
# Generation 266 Max fitness: -5.878005740189707e-05 Min fitness: -0.04622959842309715 Avg fitness: -0.026524531707093468
# Generation 267 Max fitness: -5.878005740189707e-05 Min fitness: -0.04555544421458513 Avg fitness: -0.02621035831792479
# Generation 268 Max fitness: -5.878005740189707e-05 Min fitness: -0.04487755153641759 Avg fitness: -0.025853855172034035
# Generation 269 Max fitness: -5.878005740189707e-05 Min fitness: -0.04376279159508878 Avg fitness: -0.02546269387257179
# Generation 270 Max fitness: -5.878005740189707e-05 Min fitness: -0.04313845536559768 Avg fitness: -0.025201834001527264
# Generation 271 Max fitness: -5.878005740189707e-05 Min fitness: -0.04258466790807558 Avg fitness: -0.024897065786991007
# Generation 272 Max fitness: -5.878005740189707e-05 Min fitness: -0.04202408704842342 Avg fitness: -0.024599024115614588
# Generation 273 Max fitness: -7.863468255986383e-06 Min fitness: -0.04143637548507162 Avg fitness: -0.02426426797110937
# Generation 274 Max fitness: -7.863468255986383e-06 Min fitness: -0.040811045064748974 Avg fitness: -0.024002773532450696
# Generation 275 Max fitness: -7.863468255986383e-06 Min fitness: -0.04037950652414546 Avg fitness: -0.023746939001805332
# Generation 276 Max fitness: -7.863468255986383e-06 Min fitness: -0.03979001571351781 Avg fitness: -0.023476077332835264
# Generation 277 Max fitness: -7.863468255986383e-06 Min fitness: -0.03909236036907726 Avg fitness: -0.023192248243029633
# Generation 278 Max fitness: -7.863468255986383e-06 Min fitness: -0.03871598726365233 Avg fitness: -0.022994118053334876
# Generation 279 Max fitness: -7.863468255986383e-06 Min fitness: -0.03829427227332605 Avg fitness: -0.022720444850067658
# Generation 280 Max fitness: -7.863468255986383e-06 Min fitness: -0.03759627930390763 Avg fitness: -0.022436004879828778
# Generation 281 Max fitness: -7.863468255986383e-06 Min fitness: -0.0372406871496922 Avg fitness: -0.022254749594957476
# Generation 282 Max fitness: -7.863468255986383e-06 Min fitness: -0.03688429706664276 Avg fitness: -0.022000473159821718
# Generation 283 Max fitness: -7.863468255986383e-06 Min fitness: -0.036409860616058 Avg fitness: -0.021776322619078213
# Generation 284 Max fitness: -7.863468255986383e-06 Min fitness: -0.035773125091613345 Avg fitness: -0.021495933934627096
# Generation 285 Max fitness: -7.863468255986383e-06 Min fitness: -0.035334457798675833 Avg fitness: -0.02125419204250041
# Generation 286 Max fitness: -7.863468255986383e-06 Min fitness: -0.03500660388481658 Avg fitness: -0.021078100566394375
# Generation 287 Max fitness: -7.863468255986383e-06 Min fitness: -0.03452833276030143 Avg fitness: -0.020891162083488995
# Generation 288 Max fitness: -7.863468255986383e-06 Min fitness: -0.03406736112882869 Avg fitness: -0.020646019875107426
# Generation 289 Max fitness: -7.863468255986383e-06 Min fitness: -0.03363040831397757 Avg fitness: -0.020407785661459458
# Generation 290 Max fitness: -7.863468255986383e-06 Min fitness: -0.03320350774670089 Avg fitness: -0.0201857279055628
# Generation 291 Max fitness: -7.863468255986383e-06 Min fitness: -0.03291028484522007 Avg fitness: -0.020002825130259635
# Generation 292 Max fitness: -7.863468255986383e-06 Min fitness: -0.032531401795222625 Avg fitness: -0.019804484511893712
# Generation 293 Max fitness: -7.863468255986383e-06 Min fitness: -0.0322262267150365 Avg fitness: -0.019630834711014518
# Generation 294 Max fitness: -7.863468255986383e-06 Min fitness: -0.03170290971065293 Avg fitness: -0.0194393174554448
# Generation 295 Max fitness: -7.863468255986383e-06 Min fitness: -0.031276267731315754 Avg fitness: -0.01925532872198987
# Generation 296 Max fitness: -7.863468255986383e-06 Min fitness: -0.03092266476119787 Avg fitness: -0.01907329123595266
# Generation 297 Max fitness: -7.863468255986383e-06 Min fitness: -0.030418472795056606 Avg fitness: -0.01888533744924547
# Generation 298 Max fitness: -7.863468255986383e-06 Min fitness: -0.030095372587989777 Avg fitness: -0.01866883514739654
# Generation 299 Max fitness: -7.863468255986383e-06 Min fitness: -0.02993752445576059 Avg fitness: -0.018551808452569516
# Generation 300 Max fitness: -7.863468255986383e-06 Min fitness: -0.029451966110947803 Avg fitness: -0.01837049650470322
# Generation 301 Max fitness: -7.863468255986383e-06 Min fitness: -0.02913372499311484 Avg fitness: -0.01821904327727933
# Generation 302 Max fitness: -7.863468255986383e-06 Min fitness: -0.028830791122080868 Avg fitness: -0.018077917362105234
# Generation 303 Max fitness: -7.863468255986383e-06 Min fitness: -0.028688040901655998 Avg fitness: -0.017962766368367817
# Generation 304 Max fitness: -7.863468255986383e-06 Min fitness: -0.028376737813131325 Avg fitness: -0.017836437203269988
# Generation 305 Max fitness: -7.863468255986383e-06 Min fitness: -0.028132853742106945 Avg fitness: -0.017726839152063443
# Generation 306 Max fitness: -7.863468255986383e-06 Min fitness: -0.02789168991759916 Avg fitness: -0.017604844230849345
# Generation 307 Max fitness: -7.863468255986383e-06 Min fitness: -0.027517158753950666 Avg fitness: -0.017461058539721318
# Generation 308 Max fitness: -7.863468255986383e-06 Min fitness: -0.027251468137298396 Avg fitness: -0.01733312822307557
# Generation 309 Max fitness: -7.863468255986383e-06 Min fitness: -0.027006534153898643 Avg fitness: -0.017220737446027604
# Generation 310 Max fitness: -7.863468255986383e-06 Min fitness: -0.026779600124353653 Avg fitness: -0.017116403815026816
# Generation 311 Max fitness: -7.863468255986383e-06 Min fitness: -0.026528685400052487 Avg fitness: -0.01696214419845542
# Generation 312 Max fitness: -7.863468255986383e-06 Min fitness: -0.026372475455735844 Avg fitness: -0.01685816986891739
# Generation 313 Max fitness: -7.863468255986383e-06 Min fitness: -0.026122850194533864 Avg fitness: -0.016744461830751307
# Generation 314 Max fitness: -7.863468255986383e-06 Min fitness: -0.02588515785594314 Avg fitness: -0.016660590638681673
# Generation 315 Max fitness: -7.863468255986383e-06 Min fitness: -0.025701718677264895 Avg fitness: -0.016557776585032682
# Generation 316 Max fitness: -7.863468255986383e-06 Min fitness: -0.02551224622100745 Avg fitness: -0.01646109193639654
# Generation 317 Max fitness: -7.863468255986383e-06 Min fitness: -0.0253310537145921 Avg fitness: -0.016368285644306646
# Generation 318 Max fitness: -7.863468255986383e-06 Min fitness: -0.02508700018279708 Avg fitness: -0.016239324979101147
# Generation 319 Max fitness: -7.863468255986383e-06 Min fitness: -0.024924271244322505 Avg fitness: -0.016138761631846115
# Generation 320 Max fitness: -7.863468255986383e-06 Min fitness: -0.024768515312092676 Avg fitness: -0.0160599494910688
# Generation 321 Max fitness: -7.863468255986383e-06 Min fitness: -0.02451908212204157 Avg fitness: -0.015947233627235546
# Generation 322 Max fitness: -7.863468255986383e-06 Min fitness: -0.024320103710303576 Avg fitness: -0.015841152805448018
# Generation 323 Max fitness: -7.863468255986383e-06 Min fitness: -0.024167050470439544 Avg fitness: -0.01573406772466008
# Generation 324 Max fitness: -7.863468255986383e-06 Min fitness: -0.023987477166211857 Avg fitness: -0.01563121700686462
# Generation 325 Max fitness: -7.863468255986383e-06 Min fitness: -0.023827540197654096 Avg fitness: -0.015546351022826886
# Generation 326 Max fitness: -7.863468255986383e-06 Min fitness: -0.023638232523168323 Avg fitness: -0.01547921854111496
# Generation 327 Max fitness: -7.863468255986383e-06 Min fitness: -0.023489776873465207 Avg fitness: -0.015397820962139722
# Generation 328 Max fitness: -7.863468255986383e-06 Min fitness: -0.02328615977497317 Avg fitness: -0.015271890491581556
# Generation 329 Max fitness: -7.863468255986383e-06 Min fitness: -0.023071133179159986 Avg fitness: -0.015173134391599523
# Generation 330 Max fitness: -7.863468255986383e-06 Min fitness: -0.022949292676789135 Avg fitness: -0.01512747430851941
# Generation 331 Max fitness: -7.863468255986383e-06 Min fitness: -0.022825331964709594 Avg fitness: -0.015061412857875836
# Generation 332 Max fitness: -7.863468255986383e-06 Min fitness: -0.022692259441711493 Avg fitness: -0.01497398615939478
# Generation 333 Max fitness: -7.863468255986383e-06 Min fitness: -0.022551397486703095 Avg fitness: -0.014900828456384895
# Generation 334 Max fitness: -7.863468255986383e-06 Min fitness: -0.022340324081117746 Avg fitness: -0.014813049759616316
# Generation 335 Max fitness: -7.863468255986383e-06 Min fitness: -0.02222476625651515 Avg fitness: -0.014743868971327128
# Generation 336 Max fitness: -7.863468255986383e-06 Min fitness: -0.02208644894795575 Avg fitness: -0.014646236458104067
# Generation 337 Max fitness: -7.863468255986383e-06 Min fitness: -0.021954504096349137 Avg fitness: -0.014583405683596408
# Generation 338 Max fitness: -7.863468255986383e-06 Min fitness: -0.021838402615616537 Avg fitness: -0.014518396770728983
# Generation 339 Max fitness: -7.863468255986383e-06 Min fitness: -0.02169129797471203 Avg fitness: -0.014437040990335355
# Generation 340 Max fitness: -7.863468255986383e-06 Min fitness: -0.021608172773770362 Avg fitness: -0.014367540494351952
# Generation 341 Max fitness: -7.863468255986383e-06 Min fitness: -0.021444132953150175 Avg fitness: -0.014293350228005392
# Generation 342 Max fitness: -7.863468255986383e-06 Min fitness: -0.021333656975555226 Avg fitness: -0.014205010343965523
# Generation 343 Max fitness: -7.863468255986383e-06 Min fitness: -0.0211809996077561 Avg fitness: -0.014142375580110608
# Generation 344 Max fitness: -7.863468255986383e-06 Min fitness: -0.021123058566507202 Avg fitness: -0.0140869429829007
# Generation 345 Max fitness: -7.863468255986383e-06 Min fitness: -0.021017847688461155 Avg fitness: -0.014005996150413848
# Generation 346 Max fitness: -7.863468255986383e-06 Min fitness: -0.020940618611879014 Avg fitness: -0.013953511891062528
# Generation 347 Max fitness: -7.863468255986383e-06 Min fitness: -0.020804456181369058 Avg fitness: -0.013874426478836362
# Generation 348 Max fitness: -7.863468255986383e-06 Min fitness: -0.020680671304854625 Avg fitness: -0.0138305344824273
# Generation 349 Max fitness: -7.863468255986383e-06 Min fitness: -0.020535708992412527 Avg fitness: -0.01377750076328308
# Generation 350 Max fitness: -7.863468255986383e-06 Min fitness: -0.020432689093231593 Avg fitness: -0.013725787786357876
# Generation 351 Max fitness: -7.863468255986383e-06 Min fitness: -0.020291964685861696 Avg fitness: -0.013679091298929878
# Generation 352 Max fitness: -7.863468255986383e-06 Min fitness: -0.0201866199921511 Avg fitness: -0.01362119993398161
# Generation 353 Max fitness: -7.863468255986383e-06 Min fitness: -0.02001941480298064 Avg fitness: -0.013539220419731749
# Generation 354 Max fitness: -7.863468255986383e-06 Min fitness: -0.019885451206111293 Avg fitness: -0.013488456504114413
# Generation 355 Max fitness: -7.863468255986383e-06 Min fitness: -0.019761212302388476 Avg fitness: -0.013411381156214451
# Generation 356 Max fitness: -7.863468255986383e-06 Min fitness: -0.019615162971202693 Avg fitness: -0.013334088674397287
# Generation 357 Max fitness: -7.863468255986383e-06 Min fitness: -0.019499115214696494 Avg fitness: -0.013269407798920984
# Generation 358 Max fitness: -7.863468255986383e-06 Min fitness: -0.019447814600251134 Avg fitness: -0.013213637189935611
# Generation 359 Max fitness: -7.863468255986383e-06 Min fitness: -0.019325984688240316 Avg fitness: -0.013133680924916341
# Generation 360 Max fitness: -7.863468255986383e-06 Min fitness: -0.01928947663164826 Avg fitness: -0.013096660155005997
# Generation 361 Max fitness: -7.863468255986383e-06 Min fitness: -0.01923147352777177 Avg fitness: -0.013045623185083394
# Generation 362 Max fitness: -7.863468255986383e-06 Min fitness: -0.019141753542682327 Avg fitness: -0.012992966646869832
# Generation 363 Max fitness: -7.863468255986383e-06 Min fitness: -0.019036890857155653 Avg fitness: -0.012942301211805523
# Generation 364 Max fitness: -7.863468255986383e-06 Min fitness: -0.0189634728508129 Avg fitness: -0.012900295392162156
# Generation 365 Max fitness: -7.863468255986383e-06 Min fitness: -0.018821550182243185 Avg fitness: -0.012826210169352863
# Generation 366 Max fitness: -7.863468255986383e-06 Min fitness: -0.018763457144332363 Avg fitness: -0.012765039323374828
# Generation 367 Max fitness: -7.863468255986383e-06 Min fitness: -0.0186583354484956 Avg fitness: -0.01270633326732413
# Generation 368 Max fitness: -7.863468255986383e-06 Min fitness: -0.018558474504711486 Avg fitness: -0.012651841083939411
# Generation 369 Max fitness: -7.1357715412112555e-06 Min fitness: -0.018441567507675893 Avg fitness: -0.012567047910360358
# Generation 370 Max fitness: -7.1357715412112555e-06 Min fitness: -0.018362214671596044 Avg fitness: -0.012510012052244474
# Generation 371 Max fitness: -7.1357715412112555e-06 Min fitness: -0.018271701214107816 Avg fitness: -0.012440594044644891
# Generation 372 Max fitness: -7.1357715412112555e-06 Min fitness: -0.018192514448186703 Avg fitness: -0.012368815959162952
# Generation 373 Max fitness: -7.1357715412112555e-06 Min fitness: -0.01815898272480876 Avg fitness: -0.012312359032959483
# Generation 374 Max fitness: -7.1357715412112555e-06 Min fitness: -0.018033937710318027 Avg fitness: -0.012255520801961147
# Generation 375 Max fitness: -7.1357715412112555e-06 Min fitness: -0.01798848040080614 Avg fitness: -0.012217463591578052
# Generation 376 Max fitness: -7.1357715412112555e-06 Min fitness: -0.01790465377428585 Avg fitness: -0.01217522580941778
# Generation 377 Max fitness: -7.1357715412112555e-06 Min fitness: -0.01778914619062566 Avg fitness: -0.012117860949571603
# Generation 378 Max fitness: -7.1357715412112555e-06 Min fitness: -0.0177399162265236 Avg fitness: -0.012056291878288376
# Generation 379 Max fitness: -7.1357715412112555e-06 Min fitness: -0.017674515261674517 Avg fitness: -0.012020385897263534
# Generation 380 Max fitness: -5.800227791841195e-06 Min fitness: -0.01760179654111771 Avg fitness: -0.011966104091719715
# Generation 381 Max fitness: -5.800227791841195e-06 Min fitness: -0.01753178651014664 Avg fitness: -0.011925762128791194
# Generation 382 Max fitness: -5.800227791841195e-06 Min fitness: -0.017479587781552564 Avg fitness: -0.011864526344069658
# ...
# Generation 9874 Max fitness: -2.9711669791154804e-08 Min fitness: -0.00011907427191604203 Avg fitness: -6.0228677811881905e-05
# Generation 9875 Max fitness: -2.9711669791154804e-08 Min fitness: -0.00011907427191604203 Avg fitness: -6.0228677811881905e-05
# Generation 9876 Max fitness: -2.9711669791154804e-08 Min fitness: -0.00011907427191604203 Avg fitness: -6.0228677811881905e-05
# Generation 9877 Max fitness: -2.9711669791154804e-08 Min fitness: -0.00011907427191604203 Avg fitness: -6.0228677811881905e-05
# Generation 9878 Max fitness: -2.9711669791154804e-08 Min fitness: -0.00011907427191604203 Avg fitness: -6.0228677811881905e-05
# Generation 9879 Max fitness: -2.9711669791154804e-08 Min fitness: -0.00011907427191604203 Avg fitness: -6.0228677811881905e-05
# Generation 9880 Max fitness: -2.9711669791154804e-08 Min fitness: -0.00011900762792993458 Avg fitness: -6.022561509619915e-05
# Generation 9881 Max fitness: -2.9711669791154804e-08 Min fitness: -0.00011900762792993458 Avg fitness: -6.022561509619915e-05
# Generation 9882 Max fitness: -2.9711669791154804e-08 Min fitness: -0.00011900762792993458 Avg fitness: -6.022561509619915e-05
# Generation 9883 Max fitness: -2.9711669791154804e-08 Min fitness: -0.00011900762792993458 Avg fitness: -6.022561509619915e-05
# Generation 9884 Max fitness: -2.9711669791154804e-08 Min fitness: -0.00011900762792993458 Avg fitness: -6.022561509619915e-05
# Generation 9885 Max fitness: -2.9711669791154804e-08 Min fitness: -0.00011900762792993458 Avg fitness: -6.022561509619915e-05
# Generation 9886 Max fitness: -2.9711669791154804e-08 Min fitness: -0.0001189588483251347 Avg fitness: -6.0183667119406215e-05
# Generation 9887 Max fitness: -2.9711669791154804e-08 Min fitness: -0.0001189588483251347 Avg fitness: -6.0183667119406215e-05
# Generation 9888 Max fitness: -2.9711669791154804e-08 Min fitness: -0.0001189588483251347 Avg fitness: -6.0183667119406215e-05
# Generation 9889 Max fitness: -2.9711669791154804e-08 Min fitness: -0.0001189588483251347 Avg fitness: -6.0183667119406215e-05
# Generation 9890 Max fitness: -2.9711669791154804e-08 Min fitness: -0.0001189588483251347 Avg fitness: -6.0183667119406215e-05
# Generation 9891 Max fitness: -2.9711669791154804e-08 Min fitness: -0.0001189588483251347 Avg fitness: -6.0183667119406215e-05
# Generation 9892 Max fitness: -2.9711669791154804e-08 Min fitness: -0.0001189588483251347 Avg fitness: -6.0183667119406215e-05
# Generation 9893 Max fitness: -2.9711669791154804e-08 Min fitness: -0.0001189588483251347 Avg fitness: -6.0183667119406215e-05
# Generation 9894 Max fitness: -2.9711669791154804e-08 Min fitness: -0.0001189588483251347 Avg fitness: -6.0183667119406215e-05
# Generation 9895 Max fitness: -2.9711669791154804e-08 Min fitness: -0.0001189588483251347 Avg fitness: -6.0183667119406215e-05
# Generation 9896 Max fitness: -2.9711669791154804e-08 Min fitness: -0.0001189588483251347 Avg fitness: -6.0183667119406215e-05
# Generation 9897 Max fitness: -2.9711669791154804e-08 Min fitness: -0.0001189588483251347 Avg fitness: -6.0183667119406215e-05
# Generation 9898 Max fitness: -2.9711669791154804e-08 Min fitness: -0.0001189588483251347 Avg fitness: -6.0183667119406215e-05
# Generation 9899 Max fitness: -2.9711669791154804e-08 Min fitness: -0.0001189588483251347 Avg fitness: -6.0183667119406215e-05
# Generation 9900 Max fitness: -2.9711669791154804e-08 Min fitness: -0.0001189519020503571 Avg fitness: -6.0159890392144886e-05
# Generation 9901 Max fitness: -2.9711669791154804e-08 Min fitness: -0.0001189519020503571 Avg fitness: -6.0159890392144886e-05
# Generation 9902 Max fitness: -2.9711669791154804e-08 Min fitness: -0.0001189519020503571 Avg fitness: -6.0159890392144886e-05
# Generation 9903 Max fitness: -2.9711669791154804e-08 Min fitness: -0.00011890527571034593 Avg fitness: -6.0156843778499434e-05
# Generation 9904 Max fitness: -2.9711669791154804e-08 Min fitness: -0.00011890527571034593 Avg fitness: -6.0156843778499434e-05
# Generation 9905 Max fitness: -2.9711669791154804e-08 Min fitness: -0.00011890527571034593 Avg fitness: -6.0156843778499434e-05
# Generation 9906 Max fitness: -2.9711669791154804e-08 Min fitness: -0.00011890200101483117 Avg fitness: -6.013335961354067e-05
# Generation 9907 Max fitness: -2.9711669791154804e-08 Min fitness: -0.00011888476147292604 Avg fitness: -6.0114447082659164e-05
# Generation 9908 Max fitness: -2.9711669791154804e-08 Min fitness: -0.00011888476147292604 Avg fitness: -6.0114447082659164e-05
# Generation 9909 Max fitness: -2.9711669791154804e-08 Min fitness: -0.00011888476147292604 Avg fitness: -6.0114447082659164e-05
# Generation 9910 Max fitness: -2.9711669791154804e-08 Min fitness: -0.00011886686622264442 Avg fitness: -6.0080028417522114e-05
# Generation 9911 Max fitness: -2.9711669791154804e-08 Min fitness: -0.00011886686622264442 Avg fitness: -6.0080028417522114e-05
# Generation 9912 Max fitness: -2.9711669791154804e-08 Min fitness: -0.00011886686622264442 Avg fitness: -6.0080028417522114e-05
# Generation 9913 Max fitness: -2.9711669791154804e-08 Min fitness: -0.0001188591912330006 Avg fitness: -6.003528180479525e-05
# Generation 9914 Max fitness: -2.9711669791154804e-08 Min fitness: -0.0001188591912330006 Avg fitness: -6.003528180479525e-05
# Generation 9915 Max fitness: -2.9711669791154804e-08 Min fitness: -0.0001188591912330006 Avg fitness: -6.003528180479525e-05
# Generation 9916 Max fitness: -2.9711669791154804e-08 Min fitness: -0.0001188591912330006 Avg fitness: -6.003528180479525e-05
# Generation 9917 Max fitness: -2.9711669791154804e-08 Min fitness: -0.00011882578105015806 Avg fitness: -6.0007735747458255e-05
# Generation 9918 Max fitness: -2.9711669791154804e-08 Min fitness: -0.00011882578105015806 Avg fitness: -6.0007735747458255e-05
# Generation 9919 Max fitness: -2.9711669791154804e-08 Min fitness: -0.00011880837412625578 Avg fitness: -6.0000415646090444e-05
# Generation 9920 Max fitness: -2.9711669791154804e-08 Min fitness: -0.00011880837412625578 Avg fitness: -6.0000415646090444e-05
# Generation 9921 Max fitness: -2.9711669791154804e-08 Min fitness: -0.00011880837412625578 Avg fitness: -6.0000415646090444e-05
# Generation 9922 Max fitness: -2.9711669791154804e-08 Min fitness: -0.00011880837412625578 Avg fitness: -6.0000415646090444e-05
# Generation 9923 Max fitness: -2.9711669791154804e-08 Min fitness: -0.00011880837412625578 Avg fitness: -6.0000415646090444e-05
# Generation 9924 Max fitness: -2.9711669791154804e-08 Min fitness: -0.00011880837412625578 Avg fitness: -6.0000415646090444e-05
# Generation 9925 Max fitness: -2.9711669791154804e-08 Min fitness: -0.00011880837412625578 Avg fitness: -6.0000415646090444e-05
# Generation 9926 Max fitness: -2.9711669791154804e-08 Min fitness: -0.00011880837412625578 Avg fitness: -6.0000415646090444e-05
# Generation 9927 Max fitness: -2.9711669791154804e-08 Min fitness: -0.00011880837412625578 Avg fitness: -6.0000415646090444e-05
# Generation 9928 Max fitness: -2.9711669791154804e-08 Min fitness: -0.00011880837412625578 Avg fitness: -6.0000415646090444e-05
# Generation 9929 Max fitness: -2.9711669791154804e-08 Min fitness: -0.00011880837412625578 Avg fitness: -6.0000415646090444e-05
# Generation 9930 Max fitness: -2.9711669791154804e-08 Min fitness: -0.00011880837412625578 Avg fitness: -6.0000415646090444e-05
# Generation 9931 Max fitness: -2.9711669791154804e-08 Min fitness: -0.00011880837412625578 Avg fitness: -6.0000415646090444e-05
# Generation 9932 Max fitness: -2.9711669791154804e-08 Min fitness: -0.00011880837412625578 Avg fitness: -6.0000415646090444e-05
# Generation 9933 Max fitness: -2.9711669791154804e-08 Min fitness: -0.00011880837412625578 Avg fitness: -6.0000415646090444e-05
# Generation 9934 Max fitness: -2.9711669791154804e-08 Min fitness: -0.00011880837412625578 Avg fitness: -6.0000415646090444e-05
# Generation 9935 Max fitness: -2.9711669791154804e-08 Min fitness: -0.00011880837412625578 Avg fitness: -6.0000415646090444e-05
# Generation 9936 Max fitness: -2.9711669791154804e-08 Min fitness: -0.00011880837412625578 Avg fitness: -6.0000415646090444e-05
# Generation 9937 Max fitness: -2.9711669791154804e-08 Min fitness: -0.00011880837412625578 Avg fitness: -6.0000415646090444e-05
# Generation 9938 Max fitness: -2.9711669791154804e-08 Min fitness: -0.00011880837412625578 Avg fitness: -6.0000415646090444e-05
# Generation 9939 Max fitness: -2.9711669791154804e-08 Min fitness: -0.00011880837412625578 Avg fitness: -6.0000415646090444e-05
# Generation 9940 Max fitness: -2.9711669791154804e-08 Min fitness: -0.00011879791910274218 Avg fitness: -5.9989214778119095e-05
# Generation 9941 Max fitness: -2.9711669791154804e-08 Min fitness: -0.00011879791910274218 Avg fitness: -5.9989214778119095e-05
# Generation 9942 Max fitness: -2.9711669791154804e-08 Min fitness: -0.00011874794832655855 Avg fitness: -5.9986727027006073e-05
# Generation 9943 Max fitness: -2.9711669791154804e-08 Min fitness: -0.00011871552957365417 Avg fitness: -5.9961472819028705e-05
# Generation 9944 Max fitness: -2.9711669791154804e-08 Min fitness: -0.00011871552957365417 Avg fitness: -5.9961472819028705e-05
# Generation 9945 Max fitness: -2.9711669791154804e-08 Min fitness: -0.00011871552957365417 Avg fitness: -5.9961472819028705e-05
# Generation 9946 Max fitness: -2.9711669791154804e-08 Min fitness: -0.00011870302989003267 Avg fitness: -5.9938802637352314e-05
# Generation 9947 Max fitness: -2.9711669791154804e-08 Min fitness: -0.00011863320934846211 Avg fitness: -5.992007489564464e-05
# Generation 9948 Max fitness: -2.9711669791154804e-08 Min fitness: -0.00011859325818197597 Avg fitness: -5.984702987165744e-05
# Generation 9949 Max fitness: -2.9711669791154804e-08 Min fitness: -0.00011859325818197597 Avg fitness: -5.984702987165744e-05
# Generation 9950 Max fitness: -2.9711669791154804e-08 Min fitness: -0.00011859325818197597 Avg fitness: -5.984702987165744e-05
# Generation 9951 Max fitness: -2.9711669791154804e-08 Min fitness: -0.00011852461625516675 Avg fitness: -5.981412459885247e-05
# Generation 9952 Max fitness: -2.9711669791154804e-08 Min fitness: -0.00011852461625516675 Avg fitness: -5.981412459885247e-05
# Generation 9953 Max fitness: -2.9711669791154804e-08 Min fitness: -0.00011852461625516675 Avg fitness: -5.981412459885247e-05
# Generation 9954 Max fitness: -2.9711669791154804e-08 Min fitness: -0.00011852461625516675 Avg fitness: -5.981412459885247e-05
# Generation 9955 Max fitness: -2.9711669791154804e-08 Min fitness: -0.00011852461625516675 Avg fitness: -5.981412459885247e-05
# Generation 9956 Max fitness: -2.9711669791154804e-08 Min fitness: -0.00011852461625516675 Avg fitness: -5.981412459885247e-05
# Generation 9957 Max fitness: -2.9711669791154804e-08 Min fitness: -0.00011852461625516675 Avg fitness: -5.981412459885247e-05
# Generation 9958 Max fitness: -2.9711669791154804e-08 Min fitness: -0.00011846699990158971 Avg fitness: -5.980508429094384e-05
# Generation 9959 Max fitness: -2.9711669791154804e-08 Min fitness: -0.00011846699990158971 Avg fitness: -5.980508429094384e-05
# Generation 9960 Max fitness: -2.9711669791154804e-08 Min fitness: -0.00011846699990158971 Avg fitness: -5.980508429094384e-05
# Generation 9961 Max fitness: -2.9711669791154804e-08 Min fitness: -0.00011846699990158971 Avg fitness: -5.980508429094384e-05
# Generation 9962 Max fitness: -2.9711669791154804e-08 Min fitness: -0.00011846699990158971 Avg fitness: -5.980508429094384e-05
# Generation 9963 Max fitness: -2.9711669791154804e-08 Min fitness: -0.00011846699990158971 Avg fitness: -5.980508429094384e-05
# Generation 9964 Max fitness: -2.9711669791154804e-08 Min fitness: -0.00011846699990158971 Avg fitness: -5.980508429094384e-05
# Generation 9965 Max fitness: -2.9711669791154804e-08 Min fitness: -0.00011846699990158971 Avg fitness: -5.980508429094384e-05
# Generation 9966 Max fitness: -2.9711669791154804e-08 Min fitness: -0.00011846699990158971 Avg fitness: -5.980508429094384e-05
# Generation 9967 Max fitness: -2.9711669791154804e-08 Min fitness: -0.00011845084624129143 Avg fitness: -5.976451137331042e-05
# Generation 9968 Max fitness: -2.9711669791154804e-08 Min fitness: -0.00011845084624129143 Avg fitness: -5.976451137331042e-05
# Generation 9969 Max fitness: -2.9711669791154804e-08 Min fitness: -0.00011845084624129143 Avg fitness: -5.976451137331042e-05
# Generation 9970 Max fitness: -2.9711669791154804e-08 Min fitness: -0.00011845084624129143 Avg fitness: -5.976451137331042e-05
# Generation 9971 Max fitness: -2.9711669791154804e-08 Min fitness: -0.00011836111015262052 Avg fitness: -5.973411825591413e-05
# Generation 9972 Max fitness: -2.9711669791154804e-08 Min fitness: -0.00011827602375535928 Avg fitness: -5.972791880903325e-05
# Generation 9973 Max fitness: -2.9711669791154804e-08 Min fitness: -0.00011827602375535928 Avg fitness: -5.972791880903325e-05
# Generation 9974 Max fitness: -2.9711669791154804e-08 Min fitness: -0.00011827602375535928 Avg fitness: -5.972791880903325e-05
# Generation 9975 Max fitness: -2.9711669791154804e-08 Min fitness: -0.00011827602375535928 Avg fitness: -5.972791880903325e-05
# Generation 9976 Max fitness: -2.9711669791154804e-08 Min fitness: -0.00011827602375535928 Avg fitness: -5.972791880903325e-05
# Generation 9977 Max fitness: -2.9711669791154804e-08 Min fitness: -0.00011827602375535928 Avg fitness: -5.972791880903325e-05
# Generation 9978 Max fitness: -2.9711669791154804e-08 Min fitness: -0.00011826122055358379 Avg fitness: -5.970251356699445e-05
# Generation 9979 Max fitness: -2.9711669791154804e-08 Min fitness: -0.00011824879991073622 Avg fitness: -5.9664435511850565e-05
# Generation 9980 Max fitness: -2.9711669791154804e-08 Min fitness: -0.00011824879991073622 Avg fitness: -5.9664435511850565e-05
# Generation 9981 Max fitness: -2.9711669791154804e-08 Min fitness: -0.00011824879991073622 Avg fitness: -5.9664435511850565e-05
# Generation 9982 Max fitness: -2.9711669791154804e-08 Min fitness: -0.00011824879991073622 Avg fitness: -5.9664435511850565e-05
# Generation 9983 Max fitness: -2.9711669791154804e-08 Min fitness: -0.00011824879991073622 Avg fitness: -5.9664435511850565e-05
# Generation 9984 Max fitness: -2.9711669791154804e-08 Min fitness: -0.00011824879991073622 Avg fitness: -5.9664435511850565e-05
# Generation 9985 Max fitness: -2.9711669791154804e-08 Min fitness: -0.00011814168630441824 Avg fitness: -5.963048844443013e-05
# Generation 9986 Max fitness: -2.9711669791154804e-08 Min fitness: -0.0001179294781297191 Avg fitness: -5.959721495638752e-05
# Generation 9987 Max fitness: -2.9711669791154804e-08 Min fitness: -0.0001179294781297191 Avg fitness: -5.959721495638752e-05
# Generation 9988 Max fitness: -2.9711669791154804e-08 Min fitness: -0.0001179294781297191 Avg fitness: -5.959721495638752e-05
# Generation 9989 Max fitness: -2.9711669791154804e-08 Min fitness: -0.0001179294781297191 Avg fitness: -5.959721495638752e-05
# Generation 9990 Max fitness: -2.9711669791154804e-08 Min fitness: -0.00011791060643340234 Avg fitness: -5.959527007256433e-05
# Generation 9991 Max fitness: -2.9711669791154804e-08 Min fitness: -0.0001179059028868501 Avg fitness: -5.956536047487462e-05
# Generation 9992 Max fitness: -2.9711669791154804e-08 Min fitness: -0.0001179059028868501 Avg fitness: -5.956536047487462e-05
# Generation 9993 Max fitness: -2.9711669791154804e-08 Min fitness: -0.00011788421072334021 Avg fitness: -5.95280036572873e-05
# Generation 9994 Max fitness: -2.9711669791154804e-08 Min fitness: -0.00011788421072334021 Avg fitness: -5.95280036572873e-05
# Generation 9995 Max fitness: -2.9711669791154804e-08 Min fitness: -0.00011787942731977807 Avg fitness: -5.9493225707559814e-05
# Generation 9996 Max fitness: -2.9711669791154804e-08 Min fitness: -0.00011787942731977807 Avg fitness: -5.9493225707559814e-05
# Generation 9997 Max fitness: -2.9711669791154804e-08 Min fitness: -0.00011787942731977807 Avg fitness: -5.9493225707559814e-05
# Generation 9998 Max fitness: -2.9711669791154804e-08 Min fitness: -0.00011787942731977807 Avg fitness: -5.9493225707559814e-05
# Generation 9999 Max fitness: -2.9711669791154804e-08 Min fitness: -0.00011787942731977807 Avg fitness: -5.9493225707559814e-05
